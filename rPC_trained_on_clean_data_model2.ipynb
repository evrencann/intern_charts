# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import math

# %%
height = 64
width = 128
channel = 3

# %%
clean_data_path = '/home/evren/classified_data/clean_data/clean_data_15K/'
noisy_15dB_path = '/home/evren/classified_data/noisy_data/15dB/15dB_15K/'
noisy_20dB_path = '/home/evren/classified_data/noisy_data/20dB/20dB_15K/'
noisy_25dB_path = '/home/evren/classified_data/noisy_data/25dB/25dB_15K/'
noisy_30dB_path = '/home/evren/classified_data/noisy_data/30dB/30dB_15K/'
noisy_100dB_path = '/home/evren/classified_data/noisy_data/100dB/100dB_15K/'
noisy_mix_path = '/home/evren/classified_data/noisy_data/noisy_mix/'

# %%
clean_data_files = os.listdir(clean_data_path)
noisy_15dB_files = os.listdir(noisy_15dB_path)
noisy_20dB_files = os.listdir(noisy_20dB_path)
noisy_25dB_files = os.listdir(noisy_25dB_path)
noisy_30dB_files = os.listdir(noisy_30dB_path)
noisy_100dB_files = os.listdir(noisy_100dB_path)
noisy_mix_files = os.listdir(noisy_mix_path)

# %%
clean_data = np.zeros((len(clean_data_files), height, width, channel), dtype=np.float32)
noisy_15dB = np.zeros((len(noisy_15dB_files), height, width, channel), dtype=np.float32)
noisy_20dB = np.zeros((len(noisy_20dB_files), height, width, channel), dtype=np.float32)
noisy_25dB = np.zeros((len(noisy_25dB_files), height, width, channel), dtype=np.float32)
noisy_30dB = np.zeros((len(noisy_30dB_files), height, width, channel), dtype=np.float32)
noisy_100dB = np.zeros((len(noisy_100dB_files), height, width, channel), dtype=np.float32)
noisy_mix = np.zeros((len(noisy_mix_files), height, width, channel), dtype=np.float32)

# %%
n = 0
for i in tqdm(clean_data_files):
    img = cv2.imread(clean_data_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    clean_data[n] = img
    n = n +1
# Out:
# 100%|██████████| 15000/15000 [00:09<00:00, 1541.51it/s]

# %%
n=0
for i in tqdm(noisy_15dB_files):
    img = cv2.imread(noisy_15dB_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_15dB[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:09<00:00, 1525.14it/s]

# %%
n=0
for i in tqdm(noisy_20dB_files):
    img = cv2.imread(noisy_20dB_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_20dB[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:10<00:00, 1387.30it/s]

# %%
n=0
for i in tqdm(noisy_25dB_files):
    img = cv2.imread(noisy_25dB_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_25dB[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:11<00:00, 1302.59it/s]

# %%
n=0
for i in tqdm(noisy_30dB_files):
    img = cv2.imread(noisy_30dB_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_30dB[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:09<00:00, 1660.76it/s]

# %%
n=0
for i in tqdm(noisy_100dB_files):
    img = cv2.imread(noisy_100dB_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_100dB[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:10<00:00, 1447.31it/s]

# %%
n=0
for i in tqdm(noisy_mix_files):
    img = cv2.imread(noisy_mix_path + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_mix[n] = img
    n = n+1
# Out:
# 100%|██████████| 15000/15000 [00:14<00:00, 1036.49it/s]

# %%
print(clean_data.shape)
print(noisy_15dB.shape)
print(noisy_20dB.shape)
print(noisy_25dB.shape)
print(noisy_30dB.shape)
print(noisy_100dB.shape)
print(noisy_mix.shape)
# Out:
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)
# (15000, 64, 128, 3)

# %%
# Displaying clean images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(clean_data_files[i].split('.')[0]))
    ax.set_ylabel('clean_data')
    plt.imshow(clean_data[i])
plt.show()

# Displaying noisy_15dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_15dB_files[i].split('.')[0]))
    ax.set_ylabel('noisy_15dB')
    plt.imshow(noisy_15dB[i])
plt.show()

# Displaying noisy_20dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_20dB_files[i].split('.')[0]))
    ax.set_ylabel('noisy_20dB')
    plt.imshow(noisy_20dB[i])
plt.show()

# Displaying noisy_25dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_25dB_files[i].split('.')[0]))
    ax.set_ylabel('noisy_25dB')
    plt.imshow(noisy_25dB[i])
plt.show()

# Displaying noisy_30dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_30dB_files[i].split('.')[0]))
    ax.set_ylabel('noisy_30dB')
    plt.imshow(noisy_30dB[i])
plt.show()

# Displaying noisy_100dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_100dB_files[i].split('.')[0]))
    ax.set_ylabel('noisy_100dB')
    plt.imshow(noisy_100dB[i])
plt.show()

# Displaying noisy mix images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('{}'.format(noisy_mix_files[i].split('.')[0]))
    ax.set_ylabel('noisy_mix')
    plt.imshow(noisy_mix[i])
plt.show()

# %%
model = Sequential([    
    # encoder
    Conv2D(128, (3,3), padding="same", activation="relu", input_shape=(height,width,channel)),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    MaxPooling2D((2,2),strides=(2,2)),
    
    
    # decoder
    Conv2D(8, (3,3), padding="same", activation="relu"),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    
    Conv2D(channel, (3,3), padding="same", activation="sigmoid") # sigmoid, relu 
    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 128, 128)      3584
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 128, 128)      147584
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 128, 128)      147584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 64, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 64)        73792
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 64, 64)        36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 64, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 32, 32)        18464
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 32, 32)        9248
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 16, 32)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 16, 16)         4624
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 16, 16)         2320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 8, 16)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 8, 8)           1160
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 8, 8)           584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 4, 8)           0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 4, 8)           584
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 4, 8)           584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 4, 8, 8)           0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 8, 16)          1168
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 4, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 16, 16)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 16, 32)         4640
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 16, 32)         9248
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 16, 32)         9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 32, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 32, 64)        18496
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 32, 64)        36928
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 32, 64)        36928
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 64, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 32, 64, 128)       73856
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 32, 64, 128)       147584
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 32, 64, 128)       147584
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 64, 128, 3)        3459
# =================================================================
# Total params: 984,675
# Trainable params: 984,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001), loss='mse', metrics=['accuracy'])

# %%
history = model.fit(clean_data, clean_data,
          validation_split=0.2,
          batch_size=16,
          epochs=50,
        )
# Out:
# Train on 12000 samples, validate on 3000 samples
# Epoch 1/50
# 12000/12000 [==============================] - 1036s 86ms/sample - loss: 0.0132 - accuracy: 0.2986 - val_loss: 0.0086 - val_accuracy: 0.3255
# Epoch 2/50
# 12000/12000 [==============================] - 1017s 85ms/sample - loss: 0.0080 - accuracy: 0.3331 - val_loss: 0.0075 - val_accuracy: 0.2786
# Epoch 3/50
# 12000/12000 [==============================] - 1018s 85ms/sample - loss: 0.0071 - accuracy: 0.3366 - val_loss: 0.0067 - val_accuracy: 0.3449
# Epoch 4/50
# 12000/12000 [==============================] - 1015s 85ms/sample - loss: 0.0066 - accuracy: 0.3265 - val_loss: 0.0065 - val_accuracy: 0.2647
# Epoch 5/50
# 12000/12000 [==============================] - 1055s 88ms/sample - loss: 0.0063 - accuracy: 0.3282 - val_loss: 0.0062 - val_accuracy: 0.3714
# Epoch 6/50
# 12000/12000 [==============================] - 1008s 84ms/sample - loss: 0.0061 - accuracy: 0.3331 - val_loss: 0.0061 - val_accuracy: 0.3896
# Epoch 7/50
# 12000/12000 [==============================] - 1054s 88ms/sample - loss: 0.0060 - accuracy: 0.3357 - val_loss: 0.0059 - val_accuracy: 0.2993
# Epoch 8/50
# 12000/12000 [==============================] - 1034s 86ms/sample - loss: 0.0059 - accuracy: 0.3326 - val_loss: 0.0064 - val_accuracy: 0.3203
# Epoch 9/50
# 12000/12000 [==============================] - 1058s 88ms/sample - loss: 0.0057 - accuracy: 0.3308 - val_loss: 0.0057 - val_accuracy: 0.3194
# Epoch 10/50
# 12000/12000 [==============================] - 1044s 87ms/sample - loss: 0.0056 - accuracy: 0.3293 - val_loss: 0.0057 - val_accuracy: 0.3240
# Epoch 11/50
# 12000/12000 [==============================] - 1043s 87ms/sample - loss: 0.0055 - accuracy: 0.3280 - val_loss: 0.0055 - val_accuracy: 0.3385
# Epoch 12/50
# 12000/12000 [==============================] - 1056s 88ms/sample - loss: 0.0054 - accuracy: 0.3278 - val_loss: 0.0054 - val_accuracy: 0.3190
# Epoch 13/50
# 12000/12000 [==============================] - 1062s 89ms/sample - loss: 0.0054 - accuracy: 0.3279 - val_loss: 0.0053 - val_accuracy: 0.3443
# Epoch 14/50
# 12000/12000 [==============================] - 1074s 90ms/sample - loss: 0.0053 - accuracy: 0.3287 - val_loss: 0.0052 - val_accuracy: 0.3592
# Epoch 15/50
# 12000/12000 [==============================] - 1069s 89ms/sample - loss: 0.0052 - accuracy: 0.3290 - val_loss: 0.0051 - val_accuracy: 0.3159
# Epoch 16/50
# 12000/12000 [==============================] - 1058s 88ms/sample - loss: 0.0051 - accuracy: 0.3319 - val_loss: 0.0052 - val_accuracy: 0.3363
# Epoch 17/50
# 12000/12000 [==============================] - 1107s 92ms/sample - loss: 0.0051 - accuracy: 0.3327 - val_loss: 0.0050 - val_accuracy: 0.3269
# Epoch 18/50
# 12000/12000 [==============================] - 1050s 88ms/sample - loss: 0.0050 - accuracy: 0.3333 - val_loss: 0.0049 - val_accuracy: 0.3309
# Epoch 19/50
# 12000/12000 [==============================] - 1082s 90ms/sample - loss: 0.0050 - accuracy: 0.3356 - val_loss: 0.0049 - val_accuracy: 0.3423
# Epoch 20/50
# 12000/12000 [==============================] - 1084s 90ms/sample - loss: 0.0049 - accuracy: 0.3371 - val_loss: 0.0049 - val_accuracy: 0.3316
# Epoch 21/50
# 12000/12000 [==============================] - 1106s 92ms/sample - loss: 0.0049 - accuracy: 0.3368 - val_loss: 0.0049 - val_accuracy: 0.3545
# Epoch 22/50
# 12000/12000 [==============================] - 1063s 89ms/sample - loss: 0.0048 - accuracy: 0.3375 - val_loss: 0.0048 - val_accuracy: 0.3018
# Epoch 23/50
# 12000/12000 [==============================] - 1077s 90ms/sample - loss: 0.0048 - accuracy: 0.3390 - val_loss: 0.0048 - val_accuracy: 0.3201
# Epoch 24/50
# 12000/12000 [==============================] - 1032s 86ms/sample - loss: 0.0048 - accuracy: 0.3385 - val_loss: 0.0047 - val_accuracy: 0.3442
# Epoch 25/50
# 12000/12000 [==============================] - 1038s 87ms/sample - loss: 0.0047 - accuracy: 0.3401 - val_loss: 0.0047 - val_accuracy: 0.3476
# Epoch 26/50
# 12000/12000 [==============================] - 1034s 86ms/sample - loss: 0.0047 - accuracy: 0.3393 - val_loss: 0.0047 - val_accuracy: 0.3235
# Epoch 27/50
# 12000/12000 [==============================] - 1002s 84ms/sample - loss: 0.0047 - accuracy: 0.3396 - val_loss: 0.0046 - val_accuracy: 0.3735
# Epoch 28/50
# 12000/12000 [==============================] - 1026s 85ms/sample - loss: 0.0046 - accuracy: 0.3389 - val_loss: 0.0046 - val_accuracy: 0.3449
# Epoch 29/50
# 12000/12000 [==============================] - 1053s 88ms/sample - loss: 0.0046 - accuracy: 0.3398 - val_loss: 0.0046 - val_accuracy: 0.3321
# Epoch 30/50
# 12000/12000 [==============================] - 1045s 87ms/sample - loss: 0.0046 - accuracy: 0.3393 - val_loss: 0.0046 - val_accuracy: 0.3678
# Epoch 31/50
# 12000/12000 [==============================] - 1069s 89ms/sample - loss: 0.0045 - accuracy: 0.3400 - val_loss: 0.0046 - val_accuracy: 0.3356
# Epoch 32/50
# 12000/12000 [==============================] - 1068s 89ms/sample - loss: 0.0045 - accuracy: 0.3400 - val_loss: 0.0045 - val_accuracy: 0.3495
# Epoch 33/50
# 12000/12000 [==============================] - 1062s 89ms/sample - loss: 0.0045 - accuracy: 0.3398 - val_loss: 0.0046 - val_accuracy: 0.3191
# Epoch 34/50
# 12000/12000 [==============================] - 1083s 90ms/sample - loss: 0.0045 - accuracy: 0.3395 - val_loss: 0.0045 - val_accuracy: 0.3219
# Epoch 35/50
# 12000/12000 [==============================] - 1085s 90ms/sample - loss: 0.0045 - accuracy: 0.3395 - val_loss: 0.0045 - val_accuracy: 0.3178
# Epoch 36/50
# 12000/12000 [==============================] - 1093s 91ms/sample - loss: 0.0044 - accuracy: 0.3398 - val_loss: 0.0044 - val_accuracy: 0.3573
# Epoch 37/50
# 12000/12000 [==============================] - 1096s 91ms/sample - loss: 0.0044 - accuracy: 0.3385 - val_loss: 0.0044 - val_accuracy: 0.3288
# Epoch 38/50
# 12000/12000 [==============================] - 1078s 90ms/sample - loss: 0.0044 - accuracy: 0.3393 - val_loss: 0.0044 - val_accuracy: 0.3469
# Epoch 39/50
# 12000/12000 [==============================] - 1080s 90ms/sample - loss: 0.0044 - accuracy: 0.3400 - val_loss: 0.0044 - val_accuracy: 0.3638
# Epoch 40/50
# 12000/12000 [==============================] - 1072s 89ms/sample - loss: 0.0044 - accuracy: 0.3391 - val_loss: 0.0044 - val_accuracy: 0.3303
# Epoch 41/50
# 12000/12000 [==============================] - 1081s 90ms/sample - loss: 0.0043 - accuracy: 0.3398 - val_loss: 0.0043 - val_accuracy: 0.3181
# Epoch 42/50
# 12000/12000 [==============================] - 1037s 86ms/sample - loss: 0.0043 - accuracy: 0.3390 - val_loss: 0.0043 - val_accuracy: 0.3159
# Epoch 43/50
# 12000/12000 [==============================] - 1066s 89ms/sample - loss: 0.0043 - accuracy: 0.3392 - val_loss: 0.0043 - val_accuracy: 0.3340
# Epoch 44/50
# 12000/12000 [==============================] - 1075s 90ms/sample - loss: 0.0043 - accuracy: 0.3395 - val_loss: 0.0043 - val_accuracy: 0.3175
# Epoch 45/50
# 12000/12000 [==============================] - 1065s 89ms/sample - loss: 0.0043 - accuracy: 0.3388 - val_loss: 0.0044 - val_accuracy: 0.3364
# Epoch 46/50
# 12000/12000 [==============================] - 1125s 94ms/sample - loss: 0.0043 - accuracy: 0.3389 - val_loss: 0.0043 - val_accuracy: 0.3223
# Epoch 47/50
# 12000/12000 [==============================] - 1112s 93ms/sample - loss: 0.0043 - accuracy: 0.3387 - val_loss: 0.0043 - val_accuracy: 0.3434
# Epoch 48/50
# 12000/12000 [==============================] - 1101s 92ms/sample - loss: 0.0042 - accuracy: 0.3384 - val_loss: 0.0043 - val_accuracy: 0.3453
# Epoch 49/50
# 12000/12000 [==============================] - 1076s 90ms/sample - loss: 0.0042 - accuracy: 0.3384 - val_loss: 0.0043 - val_accuracy: 0.3451
# Epoch 50/50
# 12000/12000 [==============================] - 1100s 92ms/sample - loss: 0.0042 - accuracy: 0.3393 - val_loss: 0.0042 - val_accuracy: 0.3523

# %%
plt.rcParams['figure.figsize'] = (17,6)
fig, ax1 = plt.subplots()
xepochs = range(1,len(history.history['loss']) + 1)

plt.plot(xepochs, history.history['loss'], label = 'loss')
plt.plot(xepochs, history.history['val_loss'], label = 'val_loss')
plt.title('Loss')
plt.grid(True)
plt.legend()
plt.show()

plt.plot(xepochs, history.history['accuracy'], label = 'accuracy')
plt.plot(xepochs, history.history['val_accuracy'], label = 'val_accuracy')
plt.title('Metrics (Accuracy)')
plt.grid(True)
plt.legend()
plt.show()

# %%
predicted_clean = model.predict(clean_data)
predicted_15dB = model.predict(noisy_15dB)
predicted_20dB = model.predict(noisy_20dB)
predicted_25dB = model.predict(noisy_25dB)
predicted_30dB = model.predict(noisy_30dB)
predicted_100dB = model.predict(noisy_100dB)
predicted_mix = model.predict(noisy_mix)

# %%
# Displaying predicted_clean images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_clean')
    plt.imshow(predicted_clean[i])
plt.show()

# Displaying predicted_15dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_15dB')
    plt.imshow(predicted_15dB[i])
plt.show()

# Displaying predicted_20dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_20dB')
    plt.imshow(predicted_20dB[i])
plt.show()

# Displaying predicted_25dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_25dB')
    plt.imshow(predicted_25dB[i])
plt.show()

# Displaying predicted_30dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_30dB')
    plt.imshow(predicted_30dB[i])
plt.show()

# Displaying predicted_100dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_100dB')
    plt.imshow(predicted_100dB[i])
plt.show()

# Displaying predicted_mix images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_mix')
    plt.imshow(predicted_mix[i])
plt.show()

# %%
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 255.0
    psnr = 20 * math.log10(max_pixel / math.sqrt(mse)) 
    return psnr

# %%
psnr_clean = []
psnr_15dB = []
psnr_20dB = []
psnr_25dB = []
psnr_30dB = []
psnr_100dB = []
psnr_mix = []

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on clean data
n=0
for i in range(len(predicted_clean)):
    n = n+1
    psnr = PSNR(clean_data[i], predicted_clean[i])
    psnr_clean.append(psnr)

print('{} PSNR for (clean_data, predicted_clean) calculated.'.format(n))
print('avg PSNR for clean_data :{}'.format(PSNR(clean_data, predicted_clean)))
print('max : {}'.format(max(psnr_clean)))
print('min : {}'.format(min(psnr_clean)))
# Out:
# 15000 PSNR for (clean_data, predicted_clean) calculated.
# avg PSNR for clean_data :71.9163224388
# max : 75.5066210236
# min : 66.0598187757

# %%
# Displaying psnr on clean data

xepochs = range(1,len(predicted_clean) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_clean, label = 'clean_data')
plt.title('PSNR on clean data')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 15dB
n=0
for i in range(len(predicted_15dB)):
    n = n+1
    psnr = PSNR(noisy_15dB[i], predicted_15dB[i])
    psnr_15dB.append(psnr)

print('{} PSNR for (noisy_15dB, predicted_15dB) calculated.'.format(n))
print('avg PSNR for noisy_15dB :{}'.format(PSNR(noisy_15dB, predicted_15dB)))
print('max : {}'.format(max(psnr_15dB)))
print('min : {}'.format(min(psnr_15dB)))
# Out:
# 15000 PSNR for (noisy_15dB, predicted_15dB) calculated.
# avg PSNR for noisy_15dB :70.1658717559
# max : 73.9598230331
# min : 63.5915770164

# %%
# Displaying psnr on 15dB

xepochs = range(1,len(predicted_15dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_15dB, label = '15dB')
plt.title('PSNR on 15dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 20dB
n=0
for i in range(len(predicted_20dB)):
    n = n+1
    psnr = PSNR(noisy_20dB[i], predicted_20dB[i])
    psnr_20dB.append(psnr)

print('{} PSNR for (noisy_20dB, predicted_20dB) calculated.'.format(n))
print('avg PSNR for noisy_20dB :{}'.format(PSNR(noisy_20dB, predicted_20dB)))
print('max : {}'.format(max(psnr_20dB)))
print('min : {}'.format(min(psnr_20dB)))
# Out:
# 15000 PSNR for (noisy_20dB, predicted_20dB) calculated.
# avg PSNR for noisy_20dB :70.2902624903
# max : 73.7332781373
# min : 63.0294299497

# %%
# Displaying psnr on 20dB

xepochs = range(1,len(predicted_20dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_20dB, label = '20dB')
plt.title('PSNR on 20dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 25dB
n=0
for i in range(len(predicted_25dB)):
    n = n+1
    psnr = PSNR(noisy_25dB[i], predicted_25dB[i])
    psnr_25dB.append(psnr)

print('{} PSNR for (noisy_25dB, predicted_25dB) calculated.'.format(n))
print('avg PSNR for noisy_25dB :{}'.format(PSNR(noisy_25dB, predicted_25dB)))
print('max : {}'.format(max(psnr_25dB)))
print('min : {}'.format(min(psnr_25dB)))
# Out:
# 15000 PSNR for (noisy_25dB, predicted_25dB) calculated.
# avg PSNR for noisy_25dB :70.3247335686
# max : 73.8376295252
# min : 63.5527319641

# %%
# Displaying psnr on 25dB

xepochs = range(1,len(predicted_25dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_25dB, label = '25dB')
plt.title('PSNR on 25dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 30dB
n=0
for i in range(len(predicted_30dB)):
    n = n+1
    psnr = PSNR(noisy_30dB[i], predicted_30dB[i])
    psnr_30dB.append(psnr)

print('{} PSNR for (noisy_30dB, predicted_30dB) calculated.'.format(n))
print('avg PSNR for noisy_30dB :{}'.format(PSNR(noisy_30dB, predicted_30dB)))
print('max : {}'.format(max(psnr_30dB)))
print('min : {}'.format(min(psnr_30dB)))
# Out:
# 15000 PSNR for (noisy_30dB, predicted_30dB) calculated.
# avg PSNR for noisy_30dB :70.3085245243
# max : 74.6998292871
# min : 62.0063949826

# %%
# Displaying psnr on 30dB

xepochs = range(1,len(predicted_30dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_30dB, label = '30dB')
plt.title('PSNR on 30dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 100dB
n=0
for i in range(len(predicted_100dB)):
    n = n+1
    psnr = PSNR(noisy_100dB[i], predicted_100dB[i])
    psnr_100dB.append(psnr)

print('{} PSNR for (noisy_100dB, predicted_100dB) calculated.'.format(n))
print('avg PSNR for noisy_100dB :{}'.format(PSNR(noisy_100dB, predicted_100dB)))
print('max : {}'.format(max(psnr_100dB)))
print('min : {}'.format(min(psnr_100dB)))
# Out:
# 15000 PSNR for (noisy_100dB, predicted_100dB) calculated.
# avg PSNR for noisy_100dB :69.5337069532
# max : 74.3098957134
# min : 61.6443677997

# %%
# Displaying psnr on 100dB

xepochs = range(1,len(predicted_100dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_100dB, label = '100dB')
plt.title('PSNR on 100dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on mix
n=0
for i in range(len(predicted_mix)):
    n = n+1
    psnr = PSNR(noisy_mix[i], predicted_mix[i])
    psnr_mix.append(psnr)

print('{} PSNR for (noisy_mix, predicted_mix) calculated.'.format(n))
print('avg PSNR for noisy_mix :{}'.format(PSNR(noisy_mix, predicted_mix)))
print('max : {}'.format(max(psnr_mix)))
print('min : {}'.format(min(psnr_mix)))
# Out:
# 15000 PSNR for (noisy_mix, predicted_mix) calculated.
# avg PSNR for noisy_mix :69.8359834771
# max : 74.1660745715
# min : 62.6093696889

# %%
# Displaying psnr on mix

xepochs = range(1,len(predicted_mix) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_mix, label = 'mix')
plt.title('PSNR on mix')
plt.grid(True)
plt.legend()
plt.show()
