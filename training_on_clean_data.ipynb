# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import math

# %%
height = 64
width = 128
channel = 3

# %%
clean_data_path = 'D:\\intern\\classified_data\\clean_data\\extra_clean\\extra_clean'
noisy_15dB_path = 'D:\\intern\\classified_data\\noisy_data\\15dB\\extra_15dB\\extra_15dB'
noisy_20dB_path = 'D:\\intern\\classified_data\\noisy_data\\20dB\\extra_20dB\\extra_20dB'
noisy_25dB_path = 'D:\\intern\\classified_data\\noisy_data\\25dB\\extra_25dB\\extra_25dB'
noisy_30dB_path = 'D:\\intern\\classified_data\\noisy_data\\30dB\\extra_30dB\\extra_30dB'
noisy_100dB_path = 'D:\\intern\\classified_data\\noisy_data\\100dB\\extra_100dB\\extra_100dB'
noisy_mix_path = 'D:\\intern\\classified_data\\noisy_data\\noisy_mix'

# %%
clean_data_files = os.listdir(clean_data_path)
noisy_15dB_files = os.listdir(noisy_15dB_path)
noisy_20dB_files = os.listdir(noisy_20dB_path)
noisy_25dB_files = os.listdir(noisy_25dB_path)
noisy_30dB_files = os.listdir(noisy_30dB_path)
noisy_100dB_files = os.listdir(noisy_100dB_path)
noisy_mix_files = os.listdir(noisy_mix_path)

# %%
clean_data = np.zeros((len(clean_data_files), height, width, channel), dtype=np.float32)
noisy_15dB = np.zeros((len(noisy_15dB_files), height, width, channel), dtype=np.float32)
noisy_20dB = np.zeros((len(noisy_20dB_files), height, width, channel), dtype=np.float32)
noisy_25dB = np.zeros((len(noisy_25dB_files), height, width, channel), dtype=np.float32)
noisy_30dB = np.zeros((len(noisy_30dB_files), height, width, channel), dtype=np.float32)
noisy_100dB = np.zeros((len(noisy_100dB_files), height, width, channel), dtype=np.float32)
noisy_mix = np.zeros((len(noisy_mix_files), height, width, channel), dtype=np.float32)

# %%
n = 0
for i in tqdm(clean_data_files):
    img = cv2.imread(clean_data_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    clean_data[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1396.96it/s]

# %%
n=0
for i in tqdm(noisy_15dB_files):
    img = cv2.imread(noisy_15dB_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_15dB[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1404.64it/s]

# %%
n=0
for i in tqdm(noisy_20dB_files):
    img = cv2.imread(noisy_20dB_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_20dB[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1424.73it/s]

# %%
n=0
for i in tqdm(noisy_25dB_files):
    img = cv2.imread(noisy_25dB_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_25dB[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1266.01it/s]

# %%
n=0
for i in tqdm(noisy_30dB_files):
    img = cv2.imread(noisy_30dB_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_30dB[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1370.08it/s]

# %%
n=0
for i in tqdm(noisy_100dB_files):
    img = cv2.imread(noisy_100dB_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_100dB[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1187.84it/s]

# %%
n=0
for i in tqdm(noisy_mix_files):
    img = cv2.imread(noisy_mix_path + '\\' + i, 1)
    img = cv2.resize(img, (width, height)) / 255.
    noisy_mix[n] = img
    n = n+1
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1193.49it/s]

# %%
print(clean_data.shape)
print(noisy_15dB.shape)
print(noisy_20dB.shape)
print(noisy_25dB.shape)
print(noisy_30dB.shape)
print(noisy_100dB.shape)
print(noisy_mix.shape)
# Out:
# (500, 64, 128, 3)
# (500, 64, 128, 3)
# (500, 64, 128, 3)
# (500, 64, 128, 3)
# (500, 64, 128, 3)
# (500, 64, 128, 3)
# (500, 64, 128, 3)

# %%
# Displaying clean images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{clean_data_files[i].split('.')[0]}")
    plt.imshow(clean_data[i])
plt.show()

# Displaying noisy_15dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_15dB_files[i].split('.')[0]}")
    plt.imshow(noisy_15dB[i])
plt.show()

# Displaying noisy_20dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_20dB_files[i].split('.')[0]}")
    plt.imshow(noisy_20dB[i])
plt.show()

# Displaying noisy_25dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_25dB_files[i].split('.')[0]}")
    plt.imshow(noisy_25dB[i])
plt.show()

# Displaying noisy_30dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_30dB_files[i].split('.')[0]}")
    plt.imshow(noisy_30dB[i])
plt.show()

# Displaying noisy_100dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_100dB_files[i].split('.')[0]}")
    plt.imshow(noisy_100dB[i])
plt.show()

# Displaying noisy mix images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title(f"{noisy_mix_files[i].split('.')[0]}")
    plt.imshow(noisy_mix[i])
plt.show()

# %%
model = Sequential([    
    # encoder
    Conv2D(128, (3,3), padding="same", activation="relu", input_shape=(height,width,channel)),
    BatchNormalization(),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2),strides=(2,2)),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2),strides=(2,2)),
    
    
    # decoder
    Conv2D(8, (3,3), padding="same", activation="relu"),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    Conv2D(8, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    Conv2D(16, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    Conv2D(128, (3,3), padding="same", activation="relu"),
    UpSampling2D((2,2)),
    
    Conv2D(channel, (3,3), padding="same", activation="sigmoid") # sigmoid, relu 
    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 128, 128)      3584
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 128, 128)      512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 128, 128)      147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 128, 128)      512
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 64, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 64, 64)        73792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 64, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 32, 32)        18464
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 32, 32)        128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 16, 32)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 16, 16)         4624
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 16, 16)         64
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 16, 16)         2320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 16, 16)         64
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 16, 16)         2320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 16, 16)         64
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 8, 16)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 8, 8)           1160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 4, 8, 8)           32
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 8, 8)           584
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 8, 8)           32
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 8, 8)           584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 8, 8)           32
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 4, 8)           0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 4, 8)           584
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 4, 8)           584
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 4, 8)           584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 4, 8, 8)           0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 4, 8, 16)          1168
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 4, 8, 16)          2320
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 8, 16)          2320
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 16, 16)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 16, 32)         4640
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 16, 32)         9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 32, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 32, 64)        18496
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 32, 64)        36928
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 64, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 32, 64, 128)       73856
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 32, 64, 128)       147584
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 128, 128)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 64, 128, 3)        3459
# =================================================================
# Total params: 605,043
# Trainable params: 604,003
# Non-trainable params: 1,040
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001), loss='mse', metrics=['accuracy'])

# %%
history = model.fit(clean_data, clean_data,
          validation_split=0.2,
          batch_size=16,
          epochs=50,
        )
# Out:
# Train on 400 samples, validate on 100 samples
# Epoch 1/50
# 400/400 [==============================] - 157s 393ms/sample - loss: 0.0378 - accuracy: 0.0019 - val_loss: 0.0411 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 400/400 [==============================] - 156s 391ms/sample - loss: 0.0288 - accuracy: 0.3756 - val_loss: 0.0345 - val_accuracy: 0.0411
# Epoch 3/50
# 400/400 [==============================] - 159s 398ms/sample - loss: 0.0226 - accuracy: 0.3164 - val_loss: 0.0308 - val_accuracy: 0.4959
# Epoch 4/50
# 400/400 [==============================] - 159s 398ms/sample - loss: 0.0198 - accuracy: 0.3495 - val_loss: 0.0291 - val_accuracy: 0.6717
# Epoch 5/50
# 400/400 [==============================] - 155s 389ms/sample - loss: 0.0186 - accuracy: 0.3467 - val_loss: 0.0283 - val_accuracy: 0.5741
# Epoch 6/50
# 400/400 [==============================] - 156s 390ms/sample - loss: 0.0173 - accuracy: 0.3463 - val_loss: 0.0280 - val_accuracy: 0.6285
# Epoch 7/50
# 400/400 [==============================] - 158s 396ms/sample - loss: 0.0163 - accuracy: 0.3385 - val_loss: 0.0276 - val_accuracy: 0.5078
# Epoch 8/50
# 400/400 [==============================] - 143s 358ms/sample - loss: 0.0157 - accuracy: 0.3521 - val_loss: 0.0278 - val_accuracy: 0.3861
# Epoch 9/50
# 400/400 [==============================] - 158s 395ms/sample - loss: 0.0150 - accuracy: 0.3448 - val_loss: 0.0285 - val_accuracy: 0.3169
# Epoch 10/50
# 400/400 [==============================] - 160s 400ms/sample - loss: 0.0145 - accuracy: 0.3453 - val_loss: 0.0275 - val_accuracy: 0.4623
# Epoch 11/50
# 400/400 [==============================] - 145s 363ms/sample - loss: 0.0142 - accuracy: 0.3561 - val_loss: 0.0295 - val_accuracy: 0.3659
# Epoch 12/50
# 400/400 [==============================] - 175s 437ms/sample - loss: 0.0136 - accuracy: 0.3556 - val_loss: 0.0318 - val_accuracy: 0.2205
# Epoch 13/50
# 400/400 [==============================] - 163s 407ms/sample - loss: 0.0135 - accuracy: 0.3418 - val_loss: 0.0304 - val_accuracy: 0.3189
# Epoch 14/50
# 400/400 [==============================] - 160s 399ms/sample - loss: 0.0128 - accuracy: 0.3363 - val_loss: 0.0317 - val_accuracy: 0.3303
# Epoch 15/50
# 400/400 [==============================] - 157s 392ms/sample - loss: 0.0127 - accuracy: 0.3466 - val_loss: 0.0311 - val_accuracy: 0.2892
# Epoch 16/50
# 400/400 [==============================] - 159s 397ms/sample - loss: 0.0124 - accuracy: 0.3361 - val_loss: 0.0322 - val_accuracy: 0.3086
# Epoch 17/50
# 400/400 [==============================] - 152s 380ms/sample - loss: 0.0121 - accuracy: 0.3340 - val_loss: 0.0316 - val_accuracy: 0.2601
# Epoch 18/50
# 400/400 [==============================] - 169s 423ms/sample - loss: 0.0118 - accuracy: 0.3316 - val_loss: 0.0312 - val_accuracy: 0.2848
# Epoch 19/50
# 400/400 [==============================] - 167s 417ms/sample - loss: 0.0115 - accuracy: 0.3322 - val_loss: 0.0294 - val_accuracy: 0.3472
# Epoch 20/50
# 400/400 [==============================] - 165s 413ms/sample - loss: 0.0112 - accuracy: 0.3197 - val_loss: 0.0258 - val_accuracy: 0.2246
# Epoch 21/50
# 400/400 [==============================] - 154s 385ms/sample - loss: 0.0110 - accuracy: 0.3459 - val_loss: 0.0258 - val_accuracy: 0.2518
# Epoch 22/50
# 400/400 [==============================] - 158s 396ms/sample - loss: 0.0109 - accuracy: 0.3260 - val_loss: 0.0202 - val_accuracy: 0.2643
# Epoch 23/50
# 400/400 [==============================] - 132s 331ms/sample - loss: 0.0111 - accuracy: 0.3485 - val_loss: 0.0162 - val_accuracy: 0.1869
# Epoch 24/50
# 400/400 [==============================] - 134s 335ms/sample - loss: 0.0107 - accuracy: 0.3324 - val_loss: 0.0142 - val_accuracy: 0.3187
# Epoch 25/50
# 400/400 [==============================] - 136s 341ms/sample - loss: 0.0106 - accuracy: 0.3341 - val_loss: 0.0159 - val_accuracy: 0.2462
# Epoch 26/50
# 400/400 [==============================] - 137s 341ms/sample - loss: 0.0107 - accuracy: 0.3367 - val_loss: 0.0105 - val_accuracy: 0.4368
# Epoch 27/50
# 400/400 [==============================] - 137s 343ms/sample - loss: 0.0106 - accuracy: 0.3568 - val_loss: 0.0099 - val_accuracy: 0.3712
# Epoch 28/50
# 400/400 [==============================] - 137s 342ms/sample - loss: 0.0104 - accuracy: 0.3432 - val_loss: 0.0093 - val_accuracy: 0.3693
# Epoch 29/50
# 400/400 [==============================] - 134s 336ms/sample - loss: 0.0100 - accuracy: 0.3387 - val_loss: 0.0091 - val_accuracy: 0.4216
# Epoch 30/50
# 400/400 [==============================] - 132s 331ms/sample - loss: 0.0101 - accuracy: 0.3425 - val_loss: 0.0103 - val_accuracy: 0.3262
# Epoch 31/50
# 400/400 [==============================] - 131s 329ms/sample - loss: 0.0099 - accuracy: 0.3262 - val_loss: 0.0088 - val_accuracy: 0.4493
# Epoch 32/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0097 - accuracy: 0.3438 - val_loss: 0.0096 - val_accuracy: 0.4025
# Epoch 33/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0095 - accuracy: 0.3322 - val_loss: 0.0091 - val_accuracy: 0.4356
# Epoch 34/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0094 - accuracy: 0.3382 - val_loss: 0.0090 - val_accuracy: 0.4568
# Epoch 35/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0100 - accuracy: 0.3423 - val_loss: 0.0118 - val_accuracy: 0.3153
# Epoch 36/50
# 400/400 [==============================] - 132s 331ms/sample - loss: 0.0098 - accuracy: 0.3378 - val_loss: 0.0088 - val_accuracy: 0.4142
# Epoch 37/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0094 - accuracy: 0.3387 - val_loss: 0.0090 - val_accuracy: 0.3703
# Epoch 38/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0092 - accuracy: 0.3396 - val_loss: 0.0086 - val_accuracy: 0.3917
# Epoch 39/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0090 - accuracy: 0.3333 - val_loss: 0.0090 - val_accuracy: 0.3877
# Epoch 40/50
# 400/400 [==============================] - 131s 328ms/sample - loss: 0.0089 - accuracy: 0.3472 - val_loss: 0.0087 - val_accuracy: 0.3554
# Epoch 41/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0089 - accuracy: 0.3332 - val_loss: 0.0089 - val_accuracy: 0.4329
# Epoch 42/50
# 400/400 [==============================] - 131s 327ms/sample - loss: 0.0088 - accuracy: 0.3293 - val_loss: 0.0087 - val_accuracy: 0.4628
# Epoch 43/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0090 - accuracy: 0.3477 - val_loss: 0.0085 - val_accuracy: 0.3696
# Epoch 44/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0088 - accuracy: 0.3375 - val_loss: 0.0088 - val_accuracy: 0.3664
# Epoch 45/50
# 400/400 [==============================] - 131s 329ms/sample - loss: 0.0087 - accuracy: 0.3398 - val_loss: 0.0086 - val_accuracy: 0.3600
# Epoch 46/50
# 400/400 [==============================] - 133s 332ms/sample - loss: 0.0088 - accuracy: 0.3455 - val_loss: 0.0086 - val_accuracy: 0.4273
# Epoch 47/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0086 - accuracy: 0.3366 - val_loss: 0.0094 - val_accuracy: 0.3270
# Epoch 48/50
# 400/400 [==============================] - 132s 329ms/sample - loss: 0.0085 - accuracy: 0.3248 - val_loss: 0.0083 - val_accuracy: 0.3755
# Epoch 49/50
# 400/400 [==============================] - 135s 338ms/sample - loss: 0.0084 - accuracy: 0.3400 - val_loss: 0.0082 - val_accuracy: 0.3693
# Epoch 50/50
# 400/400 [==============================] - 143s 357ms/sample - loss: 0.0084 - accuracy: 0.3381 - val_loss: 0.0096 - val_accuracy: 0.3362

# %%
plt.rcParams['figure.figsize'] = (17,6)
fig, ax1 = plt.subplots()
xepochs = range(1,len(history.history['loss']) + 1)

plt.plot(xepochs, history.history['loss'], label = 'loss')
plt.plot(xepochs, history.history['val_loss'], label = 'val_loss')
plt.title('Loss')
plt.grid(True)
plt.legend()
plt.show()

plt.plot(xepochs, history.history['accuracy'], label = 'accuracy')
plt.plot(xepochs, history.history['val_accuracy'], label = 'val_accuracy')
plt.title('Metrics (Accuracy)')
plt.grid(True)
plt.legend()
plt.show()

# %%
predicted_clean = model.predict(clean_data)
predicted_15dB = model.predict(noisy_15dB)
predicted_20dB = model.predict(noisy_20dB)
predicted_25dB = model.predict(noisy_25dB)
predicted_30dB = model.predict(noisy_30dB)
predicted_100dB = model.predict(noisy_100dB)
predicted_mix = model.predict(noisy_mix)

# %%
# Displaying predicted_clean images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_clean')
    plt.imshow(predicted_clean[i])
plt.show()

# Displaying predicted_15dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_15dB')
    plt.imshow(predicted_15dB[i])
plt.show()

# Displaying predicted_20dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_20dB')
    plt.imshow(predicted_20dB[i])
plt.show()

# Displaying predicted_25dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_25dB')
    plt.imshow(predicted_25dB[i])
plt.show()

# Displaying predicted_30dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_30dB')
    plt.imshow(predicted_30dB[i])
plt.show()

# Displaying predicted_100dB images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_100dB')
    plt.imshow(predicted_100dB[i])
plt.show()

# Displaying predicted_mix images
plt.figure(figsize=(17,4))
for i in range(1,7):
    ax = plt.subplot(1,7,i)
    ax.set_title('predicted_mix')
    plt.imshow(predicted_mix[i])
plt.show()

# %%
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 255.0
    psnr = 20 * math.log10(max_pixel / math.sqrt(mse)) 
    return psnr

# %%
psnr_clean = []
psnr_15dB = []
psnr_20dB = []
psnr_25dB = []
psnr_30dB = []
psnr_100dB = []
psnr_mix = []

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on clean data
n=0
for i in range(len(predicted_clean)):
    n = n+1
    psnr = PSNR(clean_data[i], predicted_clean[i])
    psnr_clean.append(psnr)

print(f'{n} PSNR for (clean_data, predicted_clean) calculated.')
print(f'avg PSNR for clean_data :{PSNR(clean_data, predicted_clean)}')
print(f'max : {max(psnr_clean)}')
print(f'min : {min(psnr_clean)}')
# Out:
# 500 PSNR for (clean_data, predicted_clean) calculated.
# avg PSNR for clean_data :68.44586929458353
# max : 71.4068106983731
# min : 65.19910117120999

# %%
# Displaying psnr on clean data

xepochs = range(1,len(predicted_clean) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_clean, label = 'clean_data')
plt.title('PSNR on clean data')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 15dB
n=0
for i in range(len(predicted_15dB)):
    n = n + 1
    psnr = PSNR(noisy_15dB[i], predicted_15dB[i])
    psnr_15dB.append(psnr)
    

print(f'{n} PSNR for (noisy_15dB, predicted_15dB) calculated.')
print(f'avg PSNR for 15dB :{PSNR(noisy_15dB, predicted_15dB)}')
print(f'max : {max(psnr_15dB)}')
print(f'min : {min(psnr_15dB)}')
# Out:
# 500 PSNR for (noisy_15dB, predicted_15dB) calculated.
# avg PSNR for 15dB :67.41981448945826
# max : 69.01292084235193
# min : 65.6619838722862

# %%
# Displaying psnr on 15dB data

xepochs = range(1,len(predicted_15dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_15dB, label = '15dB')
plt.title('PSNR on 15dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 20dB
n=0
for i in range(len(predicted_20dB)):
    n = n + 1
    psnr = PSNR(noisy_20dB[i], predicted_20dB[i])
    psnr_20dB.append(psnr)
    

print(f'{n} PSNR for (noisy_20dB, predicted_20dB) calculated.')
print(f'avg PSNR for 20dB :{PSNR(noisy_20dB, predicted_20dB)}')
print(f'max : {max(psnr_20dB)}')
print(f'min : {min(psnr_20dB)}')
# Out:
# 500 PSNR for (noisy_20dB, predicted_20dB) calculated.
# avg PSNR for 20dB :67.54649756700398
# max : 68.8412984796798
# min : 64.96251238246242

# %%
# Displaying psnr on 20dB data

xepochs = range(1,len(predicted_20dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_20dB, label = '20dB')
plt.title('PSNR on 20dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 25dB
n=0
for i in range(len(predicted_25dB)):
    n = n+1
    psnr = PSNR(noisy_25dB[i], predicted_25dB[i])
    psnr_25dB.append(psnr) 

print(f'{n} PSNR for (noisy_25dB, predicted_25dB) calculated.')
print(f'avg PSNR for 25dB :{PSNR(noisy_25dB, predicted_25dB)}')
print(f'max : {max(psnr_25dB)}')
print(f'min : {min(psnr_25dB)}')
# Out:
# 500 PSNR for (noisy_25dB, predicted_25dB) calculated.
# avg PSNR for 25dB :67.55737868163641
# max : 69.25894220808671
# min : 65.15318896292456

# %%
# Displaying psnr on 25dB data

xepochs = range(1,len(predicted_25dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_25dB, label = '25dB')
plt.title('PSNR on 25dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 30dB
n=0
for i in range(len(predicted_30dB)):
    n = n+1
    psnr = PSNR(noisy_30dB[i], predicted_30dB[i])
    psnr_30dB.append(psnr)

print(f'{n} PSNR for (noisy_30dB, predicted_30dB) calculated.')
print(f'avg PSNR for 30dB :{PSNR(noisy_30dB, predicted_30dB)}')
print(f'max : {max(psnr_30dB)}')
print(f'min : {min(psnr_30dB)}')
# Out:
# 500 PSNR for (noisy_30dB, predicted_30dB) calculated.
# avg PSNR for 30dB :67.52959956479118
# max : 69.78673672143981
# min : 64.40573890289458

# %%
# Displaying psnr on 30dB data

xepochs = range(1,len(predicted_30dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_30dB, label = '30dB')
plt.title('PSNR on 30dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on 100dB
n=0
for i in range(len(predicted_100dB)):
    n = n+1
    psnr = PSNR(noisy_100dB[i], predicted_100dB[i])
    psnr_100dB.append(psnr)

print(f'{n} PSNR for (noisy_100dB, predicted_100dB) calculated.')
print(f'avg PSNR for 100dB :{PSNR(noisy_100dB, predicted_100dB)}')
print(f'max : {max(psnr_100dB)}')
print(f'min : {min(psnr_100dB)}')
# Out:
# 500 PSNR for (noisy_100dB, predicted_100dB) calculated.
# avg PSNR for 100dB :61.68274864046768
# max : 70.90540773235551
# min : 55.08007467870256

# %%
# Displaying psnr on 100dB data

xepochs = range(1,len(predicted_100dB) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_100dB, label = '100dB')
plt.title('PSNR on 100dB')
plt.grid(True)
plt.legend()
plt.show()

# %%
#
#
#
#
#
#
#
#
#

# %%
# PSNR on noisy mix data
n=0
for i in range(len(predicted_mix)):
    n = n+1
    psnr = PSNR(noisy_mix[i], predicted_mix[i])
    psnr_mix.append(psnr)

print(f'{n} PSNR for (noisy_mix, predicted_mix) calculated.')
print(f'avg PSNR for noisy :{PSNR(noisy_mix, predicted_15dB)}')
print(f'max : {max(psnr_mix)}')
print(f'min : {min(psnr_mix)}')
# Out:
# 500 PSNR for (noisy_mix, predicted_mix) calculated.
# avg PSNR for noisy :63.510528590109686
# max : 69.21667029288051
# min : 55.08007467870256

# %%
# Displaying psnr on noisy mix

xepochs = range(1,len(predicted_mix) + 1)

plt.figure(figsize=(17,4))
plt.plot(xepochs, psnr_mix, label = 'noisy_mix')
plt.title('PSNR on noisy mix')
plt.grid(True)
plt.legend()
plt.show()
